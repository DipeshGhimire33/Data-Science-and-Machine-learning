# %% [markdown]
# Data set use ".CSV" in pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/bobs9/OneDrive/Desktop/Data science and Machine learning/Day_wise_learning/Day_22/titanic.csv",delimiter=",")
df = pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x = df.PassengerId
y = df.Survived
plt.barh(x,y)
plt.show()

# %%
df.loc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
mask = df.Fare > 150 
Fare_150 = df[mask]
Fare_150
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 268          269         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 311          312         1       1
# 318          319         1       1
# 332          333         0       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 498          499         0       1
# 527          528         0       1
# 557          558         0       1
# 609          610         1       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 708          709         1       1
# 716          717         1       1
# 730          731         1       1
# ...

# %%
Fare_150.shape
# Out:
# (29, 12)

# %% [markdown]
# Out of 891 only 29 passenger paid fare greater than 150$

# %%
mask = Fare_150.Sex == "female"
Fem_150 = Fare_150[mask]
Fem_150.shape
# Out:
# (19, 12)

# %% [markdown]
# Out of 29 passenger paying more than 150$, 19 were female.

# %%
Male_150 = df[(df.Fare > 150) & (df.Sex == "male")]
Male_150
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 27            28         0       1      Fortune, Mr. Charles Alexander  male
# 118          119         0       1            Baxter, Mr. Quigg Edmond  male
# 305          306         1       1      Allison, Master. Hudson Trevor  male
# 332          333         0       1           Graham, Mr. George Edward  male
# 377          378         0       1           Widener, Mr. Harry Elkins  male
# 438          439         0       1                   Fortune, Mr. Mark  male
# 527          528         0       1                  Farthing, Mr. John  male
# 557          558         0       1                 Robbins, Mr. Victor  male
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
# 737          738         1       1              Lesurer, Mr. Gustave J  male
#
#        Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
Male_150.shape
# Out:
# (10, 12)

# %% [markdown]
# 10 male passengers were paying more than 150$ in fare

# %%
H_surv = df[(df.Survived == 1) & (df.Pclass == 1)]
h_surv_per = (len(H_surv)/len(df[(df.Pclass == 1)]))*100
h_surv_per
# Out:
# 62.96296296296296

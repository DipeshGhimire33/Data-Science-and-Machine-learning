# %% [markdown]
# Pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = {
    "name" : ["Bob","Ram","Sita","Hari"],
    "age" : [19,26,14,22]  
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    name  age
# 0   Bob   19
# 1   Ram   26
# 2  Sita   14
# 3  Hari   22

# %%
x = df.name
y = df.age
plt.bar(x,y)
plt.show()

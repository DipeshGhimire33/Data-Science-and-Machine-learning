# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(pd.read_csv(r"C:\Users\bobs9\OneDrive\Desktop\Data science and Machine learning\Day_wise_learning\Day_27\titanic.csv"))

# %%
pd.crosstab(
    index = df.Sex,
    columns = df.Survived,
    margins = True,
    margins_name = "Total",
    rownames = ["gender"]
)
# Out:
# Survived    0    1  Total
# gender
# female     81  233    314
# male      468  109    577
# Total     549  342    891

# %% [markdown]
# # Get Unique value

# %%
df.Embarked.unique()
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
len(df.columns)
# Out:
# 12

# %% [markdown]
# ### Correlation vs Covariance

# %% [markdown]
# ### Covariance

# %%
df[["Age","Fare"]].cov()
# Out:
#              Age         Fare
# Age   211.019125    73.849030
# Fare   73.849030  2469.436846

# %% [markdown]
# ### Correlation

# %%
df[["Age","Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %%
plt.scatter(df.Age, df.Fare)

# %% [markdown]
# " No Correlation was seen between Age and Fare"

# %%
sample_df = df.sample(n= 300 , random_state = 999)
sample_df.mean(numeric_only = True)
# Out:
# PassengerId    451.633333
# Survived         0.366667
# Pclass           2.353333
# Age             29.880250
# SibSp            0.530000
# Parch            0.380000
# Fare            31.413222
# dtype: float64

# %%
sns.histplot(sample_df.Age, kde = True, edgecolor = "black")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
